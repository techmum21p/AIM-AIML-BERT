# %%
import tensorflow_datasets as tfds
from datasets import Dataset

# %%
ds_train_tf = tfds.load('cnn_dailymail:3.4.0', split='train[:1%]', shuffle_files=True)
ds_test_tf = tfds.load('cnn_dailymail:3.4.0', split='test[:1%]', shuffle_files=True)

train_articles, train_highlights = [], []
# Out:
# WARNING:absl:Variant folder /Users/aireesm4/tensorflow_datasets/cnn_dailymail/3.4.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /Users/aireesm4/tensorflow_datasets/cnn_dailymail/3.4.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
